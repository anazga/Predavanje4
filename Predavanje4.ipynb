# %% [markdown]
# # Numerička matematika -4. predavanje

# %% [markdown]
# ## 1. PLU rastav matrice

# %% [markdown]
# Na prethodnim predavanjima uvedena je $PLU$- faktorizacija matrice\\
#
# **DEFINICIJA** a matricu $A\in \mathbf{R}^{n\times n}$ faktorizacija oblika $PA=LU$, gdje je $P\in \mathbf{R}^{n\times n}$ permutacijaska matrica, L donjetrokutasta matrica s jedinicama na dijagonali te u gornje trokutasta nazivamo $PLU$ faktorizacija matrice $A$
#
# **Teorem**Neka je $A\in \mathbf{R}^{n\times n}$, Tada postoji permutacijska matrica $P$ takoda matrica $PA$ ima $LU$ faktorizaciju odnosno vrijedu $PA=LU$. Štoviše, postoji permutacijska matrica $P$ takva da su elementi matrice $L$ po modulu manji ili jednaki $1.$
#
# Nalaženje $PLU$- faktorizacije zadane matrice ilustrirat ćemo na jednom primjeru. Kao što smo već opisali, provodimo Gaussove eliminacije ssa standardnim pivotiranjem redaka, tj. u $k$-tom koraku na mjesto pivotnog elementa dovodimo po modulu najveći element $k$-tog stupca koji se nalazi ispod dijagonalnog elementa, čime osiguravamo stabilnost postupka. Odatle direktno slijedi da su svi elementi matrice $L$ po modulu manji ili jednaki $1$. Provedimo sada algoritam $LU$- faktorizacije s parcijalnim pivotiranjem na primjeru jedne matrice reda $4\times 4.$

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("kNbNvxmdJho")
display(vid)

# %% [markdown]
# ## Neki posebni tipovi linearnih sustava
#
#
# Podsjetimo se , složenost algoritma Gaussovih eliminacija za rješavanje linearnog sustava $Ax=b$, gdje je $A\in \mathbf{R}^{n\times n}$ iznosi $O(\frac{2n^3}{3})$. Ako matrica $A$ ima posebnu strukturu pokazuje se da se broj računskih operacija može smanjiti.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("gOfJl0ufbLg")
display(vid)

# %% [markdown]
# Pozitivna definitnost mogla bi se provjeravati i preko donjeg teorema, no to je previše numerički zahtjevno.
#
# **Teorem** Simetrična matrica $A\in \mathbf{R}^{n\times n}$ je pozitivno definitna ako i samo ako su sve njezine svojstvene vrijednosti realne i pozitivne.

# %% [markdown]
# ## Rastav Choleskog

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("H_wJ7kCUKs4")
display(vid)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/H_wJ7kCUKs4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
